# %% [markdown]
# ### Exercise 3: Scatter Plot with Annotations

# %%
# TASK: Create a scatter plot with x = [1, 2, 3, 4, 5] and y = [2, 4, 6, 8, 10].
# Annotate each point with its (x, y) value, and set the title as 'Scatter Plot with Annotations'. 
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', label='Data points')

# Annotations
for i, (x_val, y_val) in enumerate(zip(x, y)):
    plt.text(x_val, y_val, f'({x_val}, {y_val})', fontsize=10, ha='right', va='bottom')

    # Customizations
    plt.title("Scatter Plot with Annotations", fontsize=16)
    plt.xlabel("X values", fontsize=12)
    plt.ylabel("Y values", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend(fontsize=12)

    # Display
    plt.tight_layout()
    plt.show()
# Out:
# /tmp/ipykernel_3531/377265438.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=12)
# /tmp/ipykernel_3531/377265438.py:25: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# /tmp/ipykernel_3531/377265438.py:25: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
